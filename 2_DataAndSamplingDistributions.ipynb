# %% [markdown]
# <h3> Random Sampling and Sample Bias</h3><br>
# Sample<br>
# Population<br>
# Random sampling<br>
# Stratified sampling<br>
# Bias

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Selection bias</h3><br>
# Selection bias<br>
# Data snooping<br>
# Vast search effect

# %% [markdown]
# ![image.png](attachment:image.png)
# <br>
# ![image-2.png](attachment:image-2.png)
# <br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <h3>Sampling Distribution of a Statistic</h3><br>
# Sample statistic<br>
# Data distribution<br>
# Sampling distribution<br>
# Central limit theorem<br>
# Standard error<br>

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# ![image-2.png](attachment:image-2.png)
